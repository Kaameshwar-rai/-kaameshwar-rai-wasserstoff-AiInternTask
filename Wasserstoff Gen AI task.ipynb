# %% [markdown]
# # Overview
# Goal: Build a web-based chatbot that:
#
# * Lets users upload 75+ documents (PDFs, images).
#
# * Extracts and stores content in a vector database.
#
# * Allows natural language queries with citation-level answers.
#
# * Identifies and synthesizes cross-document themes.

# %% [markdown]
# ### We need to install essential libraries for:
#
# OCR (Tesseract)
#
# PDF/text extraction
#
# Vector storage & semantic search
#
# LLM interaction (OpenAI, etc.)

# %%
#importing warnings.....
import warnings
warnings.filterwarnings('ignore')

# %%
# !pip install pytesseract pdf2image PyMuPDF openai langchain chromadb tiktoken unstructured
# !apt-get install -y poppler-utils tesseract-ocr
# Out:
# Requirement already satisfied: pytesseract in c:\users\lenovo\anaconda3\lib\site-packages (0.3.13)
# Requirement already satisfied: pdf2image in c:\users\lenovo\anaconda3\lib\site-packages (1.17.0)
# Requirement already satisfied: PyMuPDF in c:\users\lenovo\anaconda3\lib\site-packages (1.25.5)
# Requirement already satisfied: openai in c:\users\lenovo\anaconda3\lib\site-packages (1.70.0)
# Requirement already satisfied: langchain in c:\users\lenovo\anaconda3\lib\site-packages (0.3.25)
# Requirement already satisfied: chromadb in c:\users\lenovo\anaconda3\lib\site-packages (1.0.9)
# Requirement already satisfied: tiktoken in c:\users\lenovo\anaconda3\lib\site-packages (0.9.0)
# Requirement already satisfied: unstructured in c:\users\lenovo\anaconda3\lib\site-packages (0.17.2)
# Requirement already satisfied: packaging>=21.3 in c:\users\lenovo\anaconda3\lib\site-packages (from pytesseract) (24.2)
# Requirement already satisfied: Pillow>=8.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pytesseract) (9.4.0)
# Requirement already satisfied: tqdm>4 in c:\users\lenovo\anaconda3\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\lenovo\anaconda3\lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\lenovo\anaconda3\lib\site-packages (from openai) (2.11.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\lenovo\anaconda3\lib\site-packages (from openai) (4.9.0)
# Requirement already satisfied: sniffio in c:\users\lenovo\anaconda3\lib\site-packages (from openai) (1.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\lenovo\anaconda3\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\lenovo\anaconda3\lib\site-packages (from openai) (4.13.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\lenovo\anaconda3\lib\site-packages (from openai) (0.9.0)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain) (6.0)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.58 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain) (0.3.60)
# Requirement already satisfied: requests<3,>=2 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain) (2.28.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain) (1.4.39)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain) (4.0.3)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain) (0.3.42)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain) (0.3.8)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (32.0.1)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (1.26.4)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (3.10.18)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: fastapi==0.115.9 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (0.115.9)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (1.33.1)
# Requirement already satisfied: typer>=0.9.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (0.15.4)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (0.21.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (1.33.1)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (0.54b1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (1.71.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (5.1.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (1.33.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (14.0.0)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (4.0.1)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (4.23.0)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (0.34.2)
# Requirement already satisfied: importlib-resources in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (9.1.2)
# Requirement already satisfied: build>=1.0.3 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (1.2.2.post1)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (1.22.0)
# Requirement already satisfied: starlette<0.46.0,>=0.40.0 in c:\users\lenovo\anaconda3\lib\site-packages (from fastapi==0.115.9->chromadb) (0.45.3)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\lenovo\anaconda3\lib\site-packages (from tiktoken) (2022.7.9)
# Requirement already satisfied: filetype in c:\users\lenovo\anaconda3\lib\site-packages (from unstructured) (1.2.0)
# Requirement already satisfied: backoff in c:\users\lenovo\anaconda3\lib\site-packages (from unstructured) (2.2.1)
# Requirement already satisfied: langdetect in c:\users\lenovo\anaconda3\lib\site-packages (from unstructured) (1.0.9)
# Requirement already satisfied: rapidfuzz in c:\users\lenovo\anaconda3\lib\site-packages (from unstructured) (3.13.0)
# Requirement already satisfied: python-iso639 in c:\users\lenovo\anaconda3\lib\site-packages (from unstructured) (2025.2.18)
# Requirement already satisfied: nltk in c:\users\lenovo\anaconda3\lib\site-packages (from unstructured) (3.7)
# Requirement already satisfied: beautifulsoup4 in c:\users\lenovo\anaconda3\lib\site-packages (from unstructured) (4.11.1)
# Requirement already satisfied: psutil in c:\users\lenovo\anaconda3\lib\site-packages (from unstructured) (5.9.0)
# Requirement already satisfied: python-oxmsg in c:\users\lenovo\anaconda3\lib\site-packages (from unstructured) (0.0.2)
# Requirement already satisfied: python-magic in c:\users\lenovo\anaconda3\lib\site-packages (from unstructured) (0.4.27)
# Requirement already satisfied: unstructured-client in c:\users\lenovo\anaconda3\lib\site-packages (from unstructured) (0.35.0)
# Requirement already satisfied: emoji in c:\users\lenovo\anaconda3\lib\site-packages (from unstructured) (2.14.1)
# Requirement already satisfied: lxml in c:\users\lenovo\anaconda3\lib\site-packages (from unstructured) (4.9.1)
# Requirement already satisfied: chardet in c:\users\lenovo\anaconda3\lib\site-packages (from unstructured) (4.0.0)
# Requirement already satisfied: dataclasses-json in c:\users\lenovo\anaconda3\lib\site-packages (from unstructured) (0.6.7)
# Requirement already satisfied: wrapt in c:\users\lenovo\anaconda3\lib\site-packages (from unstructured) (1.14.1)
# Requirement already satisfied: html5lib in c:\users\lenovo\anaconda3\lib\site-packages (from unstructured) (1.1)
# Requirement already satisfied: idna>=2.8 in c:\users\lenovo\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.4)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\lenovo\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->openai) (1.3.0)
# Requirement already satisfied: pyproject_hooks in c:\users\lenovo\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (2.0.1)
# Requirement already satisfied: colorama in c:\users\lenovo\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: certifi in c:\users\lenovo\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai) (2023.5.7)
# Requirement already satisfied: httpcore==1.* in c:\users\lenovo\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\lenovo\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\lenovo\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\lenovo\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.25.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\lenovo\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.4.1)
# Requirement already satisfied: requests-oauthlib in c:\users\lenovo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\lenovo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\lenovo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.38.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\lenovo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: durationpy>=0.7 in c:\users\lenovo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\lenovo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.26.14)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\lenovo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.58.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (1.33)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\lenovo\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: coloredlogs in c:\users\lenovo\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: sympy in c:\users\lenovo\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.11.1)
# Requirement already satisfied: protobuf in c:\users\lenovo\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.4)
# Requirement already satisfied: flatbuffers in c:\users\lenovo\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.18)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.6.1)
# Requirement already satisfied: opentelemetry-proto==1.33.1 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.33.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.69.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.33.1 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.33.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.54b1 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.54b1)
# Requirement already satisfied: opentelemetry-util-http==0.54b1 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.54b1)
# Requirement already satisfied: opentelemetry-instrumentation==0.54b1 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.54b1)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.54b1 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.54b1)
# Requirement already satisfied: asgiref~=3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-instrumentation-asgi==0.54b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: pydantic-core==2.33.1 in c:\users\lenovo\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.33.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\lenovo\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\lenovo\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\lenovo\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (2.0.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\lenovo\anaconda3\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.31.4)
# Requirement already satisfied: click<8.2,>=8.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (8.0.4)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\lenovo\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.5)
# Requirement already satisfied: websockets>=10.4 in c:\users\lenovo\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\lenovo\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\lenovo\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\lenovo\anaconda3\lib\site-packages (from beautifulsoup4->unstructured) (2.3.2.post1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\lenovo\anaconda3\lib\site-packages (from dataclasses-json->unstructured) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\lenovo\anaconda3\lib\site-packages (from dataclasses-json->unstructured) (0.9.0)
# Requirement already satisfied: webencodings in c:\users\lenovo\anaconda3\lib\site-packages (from html5lib->unstructured) (0.5.1)
# Requirement already satisfied: joblib in c:\users\lenovo\anaconda3\lib\site-packages (from nltk->unstructured) (1.1.1)
# Requirement already satisfied: olefile in c:\users\lenovo\anaconda3\lib\site-packages (from python-oxmsg->unstructured) (0.47)
# Requirement already satisfied: aiofiles>=24.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from unstructured-client->unstructured) (24.1.0)
# Requirement already satisfied: pypdf>=4.0 in c:\users\lenovo\anaconda3\lib\site-packages (from unstructured-client->unstructured) (5.5.0)
# Requirement already satisfied: nest-asyncio>=1.6.0 in c:\users\lenovo\anaconda3\lib\site-packages (from unstructured-client->unstructured) (1.6.0)
# Requirement already satisfied: cryptography>=3.1 in c:\users\lenovo\anaconda3\lib\site-packages (from unstructured-client->unstructured) (39.0.1)
# Requirement already satisfied: cffi>=1.12 in c:\users\lenovo\anaconda3\lib\site-packages (from cryptography>=3.1->unstructured-client->unstructured) (1.15.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\lenovo\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\lenovo\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: filelock in c:\users\lenovo\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.9.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\lenovo\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.3.2)
# Requirement already satisfied: zipp>=3.20 in c:\users\lenovo\anaconda3\lib\site-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.21.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\lenovo\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.58->langchain) (2.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured) (0.4.3)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\lenovo\anaconda3\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\lenovo\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.2.1)
# Requirement already satisfied: pycparser in c:\users\lenovo\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=3.1->unstructured-client->unstructured) (2.21)
# Requirement already satisfied: pyreadline3 in c:\users\lenovo\anaconda3\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\lenovo\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.8)
# 'apt-get' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# #### Installed Tools:
# pytesseract – OCR for scanned documents.
#
# pdf2image – Convert PDF pages to images.
#
# PyMuPDF (fitz) – Text-based PDF extraction.
#
# openai – For interacting with GPT models.
#
# langchain – LLM orchestration.
#
# chromadb – Vector DB for semantic search.

# %%
# !pip install pymupdf pytesseract pdf2image pillow
# !apt-get install poppler-utils tesseract-ocr
# Out:
# Requirement already satisfied: pymupdf in c:\users\lenovo\anaconda3\lib\site-packages (1.25.5)
# Requirement already satisfied: pytesseract in c:\users\lenovo\anaconda3\lib\site-packages (0.3.13)
# Requirement already satisfied: pdf2image in c:\users\lenovo\anaconda3\lib\site-packages (1.17.0)
# Requirement already satisfied: pillow in c:\users\lenovo\anaconda3\lib\site-packages (9.4.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\lenovo\anaconda3\lib\site-packages (from pytesseract) (24.2)
# 'apt-get' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# Install dependencies (uncomment if running for the first time)
# !pip install pymupdf

import fitz  # PyMuPDF
from pathlib import Path

def extract_text_from_pdf(pdf_path):
    """
    Extracts text from each page of a PDF using PyMuPDF (fitz).
    
    Parameters:
        pdf_path (str or Path): File name or path of the PDF in the same directory.

    Returns:
        dict: Dictionary with keys as 'Page_1', 'Page_2', etc., and values as text content.
    """
    doc = fitz.open(pdf_path)
    text_data = {}

    for page_num in range(len(doc)):
        page = doc.load_page(page_num)
        text = page.get_text()
        text_data[f"Page_{page_num + 1}"] = text.strip()

    doc.close()
    return text_data

# %%
# Define file name (must match exactly, case-sensitive)
pdf_path = "Resume_Kaameshwar_pdf.pdf"

# Extract text from the PDF
resume_text = extract_text_from_pdf(pdf_path)

# Preview first page content
print("Preview of Page 1:\n")
print(resume_text['Page_1'][:500])
# Out:
# Preview of Page 1:
#
# Kaameshwar Rai
# Bengaluru, KA - India | kaameshwarrai@gmail.com | +91-9910713109 | LinkedIn | Github | Kaggle
# PROFILE SUMMARY
# ●
# Analytical individual with excellent communication, programming expertise, and strong aptitude. Proven
# leadership abilities demonstrated by effectively leading project groups during undergraduate and diploma
# courses, resulting in the successful completion of projects.
# KEY SKILLS
# ●
# Tech Skills: Proficient in Python, SQL, Tableau, and an array of Python libraries including

# %% [markdown]
# ## We can see my text extraction logic using PyMuPDF is working correctly since it is able to extract text from my Resume pdf.

# %% [markdown]
# ## What We’ve Achieved So Far:
# * Successfully extracted clean text from a text-based PDF
#
# * Verified the Jupyter-compatible file path
#
# * Printed the first 500 characters to validate content

# %% [markdown]
# # Embed Text & Create Vector Store

# %%
import re

def clean_and_chunk_text(text_dict, chunk_size=400, overlap=100):
    """
    Cleans and splits extracted PDF text into overlapping chunks.
    
    Args:
        text_dict (dict): Output from extract_text_from_pdf().
        chunk_size (int): Number of characters in each chunk.
        overlap (int): Number of overlapping characters between chunks.
    
    Returns:
        List[str]: Cleaned and chunked text segments.
    """
    all_chunks = []

    for page_num, content in text_dict.items():
        # Step 1: Clean text
        cleaned = re.sub(r'\n+', '\n', content)  # collapse multiple newlines
        cleaned = re.sub(r'\s+', ' ', cleaned).strip()  # remove excess whitespace

        # Step 2: Split into overlapping chunks
        for i in range(0, len(cleaned), chunk_size - overlap):
            chunk = cleaned[i:i + chunk_size]
            if len(chunk.strip()) > 100:  # avoid garbage chunks
                all_chunks.append(chunk.strip())

    return all_chunks

# %%
resume_chunks = clean_and_chunk_text(resume_text)
print(f" Total chunks: {len(resume_chunks)}")
print("\n Sample Chunk:\n", resume_chunks[0])
# Out:
#  Total chunks: 9
#
#  Sample Chunk:
#  Kaameshwar Rai Bengaluru, KA - India | kaameshwarrai@gmail.com | +91-9910713109 | LinkedIn | Github | Kaggle PROFILE SUMMARY ● Analytical individual with excellent communication, programming expertise, and strong aptitude. Proven leadership abilities demonstrated by effectively leading project groups during undergraduate and diploma courses, resulting in the successful completion of projects. KEY

# %% [markdown]
# # Storing these chunks in a vector database (ChromaDB) using OpenAI or free local embeddings.

# %%
# !pip install langchain-community langchain chromadb openai tiktoken
# Out:
# Requirement already satisfied: langchain-community in c:\users\lenovo\anaconda3\lib\site-packages (0.3.24)
# Requirement already satisfied: langchain in c:\users\lenovo\anaconda3\lib\site-packages (0.3.25)
# Requirement already satisfied: chromadb in c:\users\lenovo\anaconda3\lib\site-packages (1.0.9)
# Requirement already satisfied: openai in c:\users\lenovo\anaconda3\lib\site-packages (1.70.0)
# Requirement already satisfied: tiktoken in c:\users\lenovo\anaconda3\lib\site-packages (0.9.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain-community) (2.9.1)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain-community) (0.3.42)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain-community) (3.11.18)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain-community) (9.1.2)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain-community) (6.0)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.59 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain-community) (0.3.60)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain-community) (1.4.39)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: requests<3,>=2 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain-community) (2.28.1)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain) (2.11.2)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain) (0.3.8)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain) (4.0.3)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: build>=1.0.3 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (1.2.2.post1)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (32.0.1)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (5.1.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (14.0.0)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (0.54b1)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (1.71.0)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (0.34.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (1.22.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (4.13.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (1.33.1)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (4.23.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (1.33.1)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (3.10.18)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (1.33.1)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (4.0.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (0.21.1)
# Requirement already satisfied: fastapi==0.115.9 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (0.115.9)
# Requirement already satisfied: typer>=0.9.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (0.15.4)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: starlette<0.46.0,>=0.40.0 in c:\users\lenovo\anaconda3\lib\site-packages (from fastapi==0.115.9->chromadb) (0.45.3)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\lenovo\anaconda3\lib\site-packages (from openai) (0.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\lenovo\anaconda3\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: sniffio in c:\users\lenovo\anaconda3\lib\site-packages (from openai) (1.2.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\lenovo\anaconda3\lib\site-packages (from openai) (4.9.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\lenovo\anaconda3\lib\site-packages (from tiktoken) (2022.7.9)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.4.4)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.6.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\lenovo\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->openai) (1.3.0)
# Requirement already satisfied: idna>=2.8 in c:\users\lenovo\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.4)
# Requirement already satisfied: pyproject_hooks in c:\users\lenovo\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (2.0.1)
# Requirement already satisfied: colorama in c:\users\lenovo\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: packaging>=19.1 in c:\users\lenovo\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (24.2)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\lenovo\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\lenovo\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: certifi in c:\users\lenovo\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (2023.5.7)
# Requirement already satisfied: httpcore==1.* in c:\users\lenovo\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\lenovo\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\lenovo\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\lenovo\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\lenovo\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.25.0)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\lenovo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.26.14)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.38.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\lenovo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: six>=1.9.0 in c:\users\lenovo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\lenovo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.58.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\lenovo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\lenovo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: requests-oauthlib in c:\users\lenovo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.59->langchain-community) (1.33)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\lenovo\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: protobuf in c:\users\lenovo\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.4)
# Requirement already satisfied: coloredlogs in c:\users\lenovo\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\lenovo\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Requirement already satisfied: sympy in c:\users\lenovo\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.11.1)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.18)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.6.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.69.2)
# Requirement already satisfied: opentelemetry-proto==1.33.1 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.33.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.33.1 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.33.1)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.54b1 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.54b1)
# Requirement already satisfied: opentelemetry-util-http==0.54b1 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.54b1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.54b1 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.54b1)
# Requirement already satisfied: opentelemetry-instrumentation==0.54b1 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.54b1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-instrumentation==0.54b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.14.1)
# Requirement already satisfied: asgiref~=3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-instrumentation-asgi==0.54b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\lenovo\anaconda3\lib\site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: pydantic-core==2.33.1 in c:\users\lenovo\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.1.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\lenovo\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community) (2.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\lenovo\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\lenovo\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (2.0.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\lenovo\anaconda3\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.31.4)
# Requirement already satisfied: click<8.2,>=8.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (8.0.4)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\lenovo\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.5)
# Requirement already satisfied: websockets>=10.4 in c:\users\lenovo\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\lenovo\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\lenovo\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\lenovo\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.2)
# Requirement already satisfied: filelock in c:\users\lenovo\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.9.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\lenovo\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.3.2)
# Requirement already satisfied: zipp>=3.20 in c:\users\lenovo\anaconda3\lib\site-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.21.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\lenovo\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.59->langchain-community) (2.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (0.4.3)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\lenovo\anaconda3\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\lenovo\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.2.1)
# Requirement already satisfied: pyreadline3 in c:\users\lenovo\anaconda3\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\lenovo\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.8)

# %%
# Install free embeddings + Chroma
# !pip install -U sentence-transformers chromadb langchain-community
# Out:
# Collecting sentence-transformers
#   Downloading sentence_transformers-4.1.0-py3-none-any.whl (345 kB)
#      -------------------------------------- 345.7/345.7 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: chromadb in c:\users\lenovo\anaconda3\lib\site-packages (1.0.9)
# Requirement already satisfied: langchain-community in c:\users\lenovo\anaconda3\lib\site-packages (0.3.24)
# Requirement already satisfied: scipy in c:\users\lenovo\anaconda3\lib\site-packages (from sentence-transformers) (1.10.0)
# Requirement already satisfied: scikit-learn in c:\users\lenovo\anaconda3\lib\site-packages (from sentence-transformers) (1.2.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\lenovo\anaconda3\lib\site-packages (from sentence-transformers) (1.12.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\lenovo\anaconda3\lib\site-packages (from sentence-transformers) (0.31.4)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\lenovo\anaconda3\lib\site-packages (from sentence-transformers) (4.13.1)
# Requirement already satisfied: Pillow in c:\users\lenovo\anaconda3\lib\site-packages (from sentence-transformers) (9.4.0)
# Requirement already satisfied: tqdm in c:\users\lenovo\anaconda3\lib\site-packages (from sentence-transformers) (4.67.1)
# Collecting transformers<5.0.0,>=4.41.0
#   Downloading transformers-4.52.1-py3-none-any.whl (10.5 MB)
#      ---------------------------------------- 10.5/10.5 MB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (6.0)
# Requirement already satisfied: pydantic>=1.9 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (2.11.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (1.33.1)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (3.10.18)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (1.26.4)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (1.33.1)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (5.1.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (32.0.1)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (0.34.2)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (4.0.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (1.33.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (4.23.0)
# Requirement already satisfied: build>=1.0.3 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (1.2.2.post1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (1.22.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (0.21.1)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (1.71.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (9.1.2)
# Requirement already satisfied: typer>=0.9.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (0.15.4)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: importlib-resources in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (0.54b1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (14.0.0)
# Requirement already satisfied: fastapi==0.115.9 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (0.115.9)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: starlette<0.46.0,>=0.40.0 in c:\users\lenovo\anaconda3\lib\site-packages (from fastapi==0.115.9->chromadb) (0.45.3)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.59 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain-community) (0.3.60)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain-community) (2.9.1)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain-community) (0.3.42)
# Requirement already satisfied: requests<3,>=2 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain-community) (2.28.1)
# Requirement already satisfied: langchain<1.0.0,>=0.3.25 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain-community) (0.3.25)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain-community) (3.11.18)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain-community) (1.4.39)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.4.4)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: packaging>=19.1 in c:\users\lenovo\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (24.2)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (2.0.1)
# Requirement already satisfied: pyproject_hooks in c:\users\lenovo\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\lenovo\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\lenovo\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\lenovo\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: httpcore==1.* in c:\users\lenovo\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.7)
# Requirement already satisfied: certifi in c:\users\lenovo\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (2023.5.7)
# Requirement already satisfied: idna in c:\users\lenovo\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (3.4)
# Requirement already satisfied: anyio in c:\users\lenovo\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (4.9.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\lenovo\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\lenovo\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.2)
# Requirement already satisfied: filelock in c:\users\lenovo\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.9.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\lenovo\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.25.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\lenovo\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\lenovo\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.38.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\lenovo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\lenovo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.26.14)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\lenovo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.58.0)
# Requirement already satisfied: requests-oauthlib in c:\users\lenovo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\lenovo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\lenovo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\lenovo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain<1.0.0,>=0.3.25->langchain-community) (0.3.8)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.59->langchain-community) (1.33)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\lenovo\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: sympy in c:\users\lenovo\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.11.1)
# Requirement already satisfied: coloredlogs in c:\users\lenovo\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\lenovo\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Requirement already satisfied: protobuf in c:\users\lenovo\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.4)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.6.1)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.18)
# Requirement already satisfied: opentelemetry-proto==1.33.1 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.33.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.33.1 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.33.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.69.2)
# Requirement already satisfied: opentelemetry-instrumentation==0.54b1 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.54b1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.54b1 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.54b1)
# Requirement already satisfied: opentelemetry-util-http==0.54b1 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.54b1)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.54b1 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.54b1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-instrumentation==0.54b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.14.1)
# Requirement already satisfied: asgiref~=3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-instrumentation-asgi==0.54b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\lenovo\anaconda3\lib\site-packages (from posthog>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\lenovo\anaconda3\lib\site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: pydantic-core==2.33.1 in c:\users\lenovo\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (2.33.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (0.4.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.1.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\lenovo\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community) (2.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\lenovo\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\lenovo\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (2.0.1)
# Collecting safetensors>=0.4.3
#   Downloading safetensors-0.5.3-cp38-abi3-win_amd64.whl (308 kB)
#      -------------------------------------- 308.9/308.9 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in c:\users\lenovo\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2022.7.9)
# Requirement already satisfied: click<8.2,>=8.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (8.0.4)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\lenovo\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: websockets>=10.4 in c:\users\lenovo\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\lenovo\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (2.2.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\lenovo\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (1.1.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\lenovo\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\lenovo\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: zipp>=3.20 in c:\users\lenovo\anaconda3\lib\site-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.21.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\lenovo\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.59->langchain-community) (2.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: sniffio>=1.1 in c:\users\lenovo\anaconda3\lib\site-packages (from anyio->httpx>=0.27.0->chromadb) (1.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\lenovo\anaconda3\lib\site-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (0.4.3)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\lenovo\anaconda3\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\lenovo\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.2.1)
# Requirement already satisfied: pyreadline3 in c:\users\lenovo\anaconda3\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\lenovo\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.8)
# Installing collected packages: safetensors, transformers, sentence-transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.24.0
#     Uninstalling transformers-4.24.0:
#       Successfully uninstalled transformers-4.24.0
# Successfully installed safetensors-0.5.3 sentence-transformers-4.1.0 transformers-4.52.1

# %%
# !pip uninstall -y torch torchvision torchaudio sentence-transformers transformers
# Out:
# Found existing installation: torch 1.12.1
# Uninstalling torch-1.12.1:
#   Successfully uninstalled torch-1.12.1
# Found existing installation: sentence-transformers 4.1.0
# Uninstalling sentence-transformers-4.1.0:
#   Successfully uninstalled sentence-transformers-4.1.0
# Found existing installation: transformers 4.52.1
# Uninstalling transformers-4.52.1:
#   Successfully uninstalled transformers-4.52.1
# WARNING: Skipping torchvision as it is not installed.
# WARNING: Skipping torchaudio as it is not installed.

# %%
# Installing required packages fresh
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu
# !pip install sentence-transformers transformers langchain-community chromadb langchain-huggingface
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cpu
# Collecting torch
#   Obtaining dependency information for torch from https://download.pytorch.org/whl/cpu/torch-2.7.0%2Bcpu-cp310-cp310-win_amd64.whl.metadata
#   Downloading https://download.pytorch.org/whl/cpu/torch-2.7.0%2Bcpu-cp310-cp310-win_amd64.whl.metadata (29 kB)
# Collecting torchvision
#   Obtaining dependency information for torchvision from https://download.pytorch.org/whl/cpu/torchvision-0.22.0%2Bcpu-cp310-cp310-win_amd64.whl.metadata
#   Downloading https://download.pytorch.org/whl/cpu/torchvision-0.22.0%2Bcpu-cp310-cp310-win_amd64.whl.metadata (6.3 kB)
# Collecting torchaudio
#   Obtaining dependency information for torchaudio from https://download.pytorch.org/whl/cpu/torchaudio-2.7.0%2Bcpu-cp310-cp310-win_amd64.whl.metadata
#   Downloading https://download.pytorch.org/whl/cpu/torchaudio-2.7.0%2Bcpu-cp310-cp310-win_amd64.whl.metadata (6.7 kB)
# Collecting sympy>=1.13.3
#   Obtaining dependency information for sympy>=1.13.3 from https://download.pytorch.org/whl/sympy-1.13.3-py3-none-any.whl.metadata
#   Downloading https://download.pytorch.org/whl/sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: jinja2 in c:\users\lenovo\anaconda3\lib\site-packages (from torch) (3.1.2)
# Requirement already satisfied: networkx in c:\users\lenovo\anaconda3\lib\site-packages (from torch) (2.8.4)
# Requirement already satisfied: fsspec in c:\users\lenovo\anaconda3\lib\site-packages (from torch) (2025.3.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\lenovo\anaconda3\lib\site-packages (from torch) (4.13.1)
# Requirement already satisfied: filelock in c:\users\lenovo\anaconda3\lib\site-packages (from torch) (3.9.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from torchvision) (9.4.0)
# Requirement already satisfied: numpy in c:\users\lenovo\anaconda3\lib\site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from jinja2->torch) (2.1.1)
# Downloading https://download.pytorch.org/whl/cpu/torch-2.7.0%2Bcpu-cp310-cp310-win_amd64.whl (215.2 MB)
#    -------------------------------------- 215.2/215.2 MB 711.1 kB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/cpu/torchvision-0.22.0%2Bcpu-cp310-cp310-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 1.7/1.7 MB 2.2 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/cpu/torchaudio-2.7.0%2Bcpu-cp310-cp310-win_amd64.whl (2.5 MB)
#    ---------------------------------------- 2.5/2.5 MB 2.8 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/sympy-1.13.3-py3-none-any.whl (6.2 MB)
#    ---------------------------------------- 6.2/6.2 MB 3.6 MB/s eta 0:00:00
# Using cached https://download.pytorch.org/whl/cpu/torch-2.7.0%2Bcpu-cp310-cp310-win_amd64.whl (215.2 MB)
# Using cached https://download.pytorch.org/whl/cpu/torchvision-0.22.0%2Bcpu-cp310-cp310-win_amd64.whl (1.7 MB)
# Using cached https://download.pytorch.org/whl/cpu/torchaudio-2.7.0%2Bcpu-cp310-cp310-win_amd64.whl (2.5 MB)
# Using cached https://download.pytorch.org/whl/sympy-1.13.3-py3-none-any.whl (6.2 MB)
# Installing collected packages: sympy, torch, torchvision, torchaudio
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.11.1
#     Uninstalling sympy-1.11.1:
#       Successfully uninstalled sympy-1.11.1
# Successfully installed sympy-1.13.3 torch-2.7.0+cpu torchaudio-2.7.0+cpu torchvision-0.22.0+cpu
# Collecting sentence-transformers
#   Using cached sentence_transformers-4.1.0-py3-none-any.whl (345 kB)
# Collecting transformers
#   Using cached transformers-4.52.1-py3-none-any.whl (10.5 MB)
# Requirement already satisfied: langchain-community in c:\users\lenovo\anaconda3\lib\site-packages (0.3.24)
# Requirement already satisfied: chromadb in c:\users\lenovo\anaconda3\lib\site-packages (1.0.9)
# Collecting langchain-huggingface
#   Downloading langchain_huggingface-0.2.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: torch>=1.11.0 in c:\users\lenovo\anaconda3\lib\site-packages (from sentence-transformers) (2.7.0+cpu)
# Requirement already satisfied: tqdm in c:\users\lenovo\anaconda3\lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: scikit-learn in c:\users\lenovo\anaconda3\lib\site-packages (from sentence-transformers) (1.2.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\lenovo\anaconda3\lib\site-packages (from sentence-transformers) (4.13.1)
# Requirement already satisfied: scipy in c:\users\lenovo\anaconda3\lib\site-packages (from sentence-transformers) (1.10.0)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\lenovo\anaconda3\lib\site-packages (from sentence-transformers) (0.31.4)
# Requirement already satisfied: Pillow in c:\users\lenovo\anaconda3\lib\site-packages (from sentence-transformers) (9.4.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\lenovo\anaconda3\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: requests in c:\users\lenovo\anaconda3\lib\site-packages (from transformers) (2.28.1)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\lenovo\anaconda3\lib\site-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\lenovo\anaconda3\lib\site-packages (from transformers) (0.5.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\lenovo\anaconda3\lib\site-packages (from transformers) (2022.7.9)
# Requirement already satisfied: numpy>=1.17 in c:\users\lenovo\anaconda3\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenovo\anaconda3\lib\site-packages (from transformers) (24.2)
# Requirement already satisfied: filelock in c:\users\lenovo\anaconda3\lib\site-packages (from transformers) (3.9.0)
# Requirement already satisfied: langchain<1.0.0,>=0.3.25 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain-community) (0.3.25)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain-community) (2.9.1)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain-community) (0.3.42)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain-community) (9.1.2)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.59 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain-community) (0.3.60)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain-community) (1.4.39)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain-community) (3.11.18)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (32.0.1)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (4.23.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (1.22.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (3.10.18)
# Requirement already satisfied: typer>=0.9.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (0.15.4)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (1.33.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (14.0.0)
# Requirement already satisfied: importlib-resources in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (1.33.1)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (0.34.2)
# Requirement already satisfied: pydantic>=1.9 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (2.11.2)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (5.1.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (1.33.1)
# Requirement already satisfied: build>=1.0.3 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (1.2.2.post1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (4.0.1)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (1.71.0)
# Requirement already satisfied: fastapi==0.115.9 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (0.115.9)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (0.54b1)
# Requirement already satisfied: starlette<0.46.0,>=0.40.0 in c:\users\lenovo\anaconda3\lib\site-packages (from fastapi==0.115.9->chromadb) (0.45.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.0)
# Requirement already satisfied: pyproject_hooks in c:\users\lenovo\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\lenovo\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (2.0.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\lenovo\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\lenovo\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: anyio in c:\users\lenovo\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (4.9.0)
# Requirement already satisfied: httpcore==1.* in c:\users\lenovo\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.7)
# Requirement already satisfied: certifi in c:\users\lenovo\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (2023.5.7)
# Requirement already satisfied: idna in c:\users\lenovo\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (3.4)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\lenovo\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\lenovo\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\lenovo\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\lenovo\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\lenovo\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.25.0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.38.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\lenovo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\lenovo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\lenovo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.26.14)
# Requirement already satisfied: requests-oauthlib in c:\users\lenovo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\lenovo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\lenovo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.58.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\lenovo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain<1.0.0,>=0.3.25->langchain-community) (0.3.8)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.59->langchain-community) (1.33)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\lenovo\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: flatbuffers in c:\users\lenovo\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Requirement already satisfied: coloredlogs in c:\users\lenovo\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: protobuf in c:\users\lenovo\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.4)
# Requirement already satisfied: sympy in c:\users\lenovo\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.3)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.18)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.6.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.33.1 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.33.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.69.2)
# Requirement already satisfied: opentelemetry-proto==1.33.1 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.33.1)
# Requirement already satisfied: opentelemetry-instrumentation==0.54b1 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.54b1)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.54b1 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.54b1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.54b1 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.54b1)
# Requirement already satisfied: opentelemetry-util-http==0.54b1 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.54b1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-instrumentation==0.54b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.14.1)
# Requirement already satisfied: asgiref~=3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-instrumentation-asgi==0.54b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\lenovo\anaconda3\lib\site-packages (from posthog>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\lenovo\anaconda3\lib\site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in c:\users\lenovo\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (0.4.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.1.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\lenovo\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\lenovo\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (2.0.1)
# Requirement already satisfied: jinja2 in c:\users\lenovo\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: networkx in c:\users\lenovo\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (2.8.4)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: click<8.2,>=8.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (8.0.4)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\lenovo\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.5)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\lenovo\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: websockets>=10.4 in c:\users\lenovo\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (2.2.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\lenovo\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (1.1.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\lenovo\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\lenovo\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.2.8)
# Requirement already satisfied: zipp>=3.20 in c:\users\lenovo\anaconda3\lib\site-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.21.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\lenovo\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.59->langchain-community) (2.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\lenovo\anaconda3\lib\site-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\lenovo\anaconda3\lib\site-packages (from anyio->httpx>=0.27.0->chromadb) (1.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.2.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (0.4.3)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\lenovo\anaconda3\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.1)
# Requirement already satisfied: pyreadline3 in c:\users\lenovo\anaconda3\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\lenovo\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.8)
# Installing collected packages: transformers, sentence-transformers, langchain-huggingface
# Successfully installed langchain-huggingface-0.2.0 sentence-transformers-4.1.0 transformers-4.52.1

# %%
# !pip uninstall -y torch torchvision torchaudio sentence-transformers transformers
# Out:
# Found existing installation: torch 2.7.0+cpu
# Uninstalling torch-2.7.0+cpu:
#   Successfully uninstalled torch-2.7.0+cpu
# Found existing installation: torchvision 0.22.0+cpu
# Uninstalling torchvision-0.22.0+cpu:
#   Successfully uninstalled torchvision-0.22.0+cpu
# Found existing installation: torchaudio 2.7.0+cpu
# Uninstalling torchaudio-2.7.0+cpu:
#   Successfully uninstalled torchaudio-2.7.0+cpu
# Found existing installation: sentence-transformers 4.1.0
# Uninstalling sentence-transformers-4.1.0:
#   Successfully uninstalled sentence-transformers-4.1.0
# Found existing installation: transformers 4.52.1
# Uninstalling transformers-4.52.1:
#   Successfully uninstalled transformers-4.52.1

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cpu
# Collecting torch
#   Obtaining dependency information for torch from https://download.pytorch.org/whl/cpu/torch-2.7.0%2Bcpu-cp310-cp310-win_amd64.whl.metadata
#   Using cached https://download.pytorch.org/whl/cpu/torch-2.7.0%2Bcpu-cp310-cp310-win_amd64.whl.metadata (29 kB)
# Collecting torchvision
#   Obtaining dependency information for torchvision from https://download.pytorch.org/whl/cpu/torchvision-0.22.0%2Bcpu-cp310-cp310-win_amd64.whl.metadata
#   Using cached https://download.pytorch.org/whl/cpu/torchvision-0.22.0%2Bcpu-cp310-cp310-win_amd64.whl.metadata (6.3 kB)
# Collecting torchaudio
#   Obtaining dependency information for torchaudio from https://download.pytorch.org/whl/cpu/torchaudio-2.7.0%2Bcpu-cp310-cp310-win_amd64.whl.metadata
#   Using cached https://download.pytorch.org/whl/cpu/torchaudio-2.7.0%2Bcpu-cp310-cp310-win_amd64.whl.metadata (6.7 kB)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\lenovo\anaconda3\lib\site-packages (from torch) (1.13.3)
# Requirement already satisfied: filelock in c:\users\lenovo\anaconda3\lib\site-packages (from torch) (3.9.0)
# Requirement already satisfied: networkx in c:\users\lenovo\anaconda3\lib\site-packages (from torch) (2.8.4)
# Requirement already satisfied: fsspec in c:\users\lenovo\anaconda3\lib\site-packages (from torch) (2025.3.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\lenovo\anaconda3\lib\site-packages (from torch) (4.13.1)
# Requirement already satisfied: jinja2 in c:\users\lenovo\anaconda3\lib\site-packages (from torch) (3.1.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from torchvision) (9.4.0)
# Requirement already satisfied: numpy in c:\users\lenovo\anaconda3\lib\site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from jinja2->torch) (2.1.1)
# Using cached https://download.pytorch.org/whl/cpu/torch-2.7.0%2Bcpu-cp310-cp310-win_amd64.whl (215.2 MB)
# Using cached https://download.pytorch.org/whl/cpu/torchvision-0.22.0%2Bcpu-cp310-cp310-win_amd64.whl (1.7 MB)
# Using cached https://download.pytorch.org/whl/cpu/torchaudio-2.7.0%2Bcpu-cp310-cp310-win_amd64.whl (2.5 MB)
# Using cached https://download.pytorch.org/whl/cpu/torch-2.7.0%2Bcpu-cp310-cp310-win_amd64.whl (215.2 MB)
# Using cached https://download.pytorch.org/whl/cpu/torchvision-0.22.0%2Bcpu-cp310-cp310-win_amd64.whl (1.7 MB)
# Using cached https://download.pytorch.org/whl/cpu/torchaudio-2.7.0%2Bcpu-cp310-cp310-win_amd64.whl (2.5 MB)
# Installing collected packages: torch, torchvision, torchaudio
# Successfully installed torch-2.7.0+cpu torchaudio-2.7.0+cpu torchvision-0.22.0+cpu

# %%
# !pip install sentence-transformers transformers langchain-huggingface langchain-community chromadb
# Out:
# Collecting sentence-transformers
#   Using cached sentence_transformers-4.1.0-py3-none-any.whl (345 kB)
# Collecting transformers
#   Using cached transformers-4.52.1-py3-none-any.whl (10.5 MB)
# Requirement already satisfied: langchain-huggingface in c:\users\lenovo\anaconda3\lib\site-packages (0.2.0)
# Requirement already satisfied: langchain-community in c:\users\lenovo\anaconda3\lib\site-packages (0.3.24)
# Requirement already satisfied: chromadb in c:\users\lenovo\anaconda3\lib\site-packages (1.0.9)
# Requirement already satisfied: torch>=1.11.0 in c:\users\lenovo\anaconda3\lib\site-packages (from sentence-transformers) (2.7.0+cpu)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\lenovo\anaconda3\lib\site-packages (from sentence-transformers) (4.13.1)
# Requirement already satisfied: Pillow in c:\users\lenovo\anaconda3\lib\site-packages (from sentence-transformers) (9.4.0)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\lenovo\anaconda3\lib\site-packages (from sentence-transformers) (0.31.4)
# Requirement already satisfied: tqdm in c:\users\lenovo\anaconda3\lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: scikit-learn in c:\users\lenovo\anaconda3\lib\site-packages (from sentence-transformers) (1.2.1)
# Requirement already satisfied: scipy in c:\users\lenovo\anaconda3\lib\site-packages (from sentence-transformers) (1.10.0)
# Requirement already satisfied: filelock in c:\users\lenovo\anaconda3\lib\site-packages (from transformers) (3.9.0)
# Requirement already satisfied: requests in c:\users\lenovo\anaconda3\lib\site-packages (from transformers) (2.28.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\lenovo\anaconda3\lib\site-packages (from transformers) (0.5.3)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\lenovo\anaconda3\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenovo\anaconda3\lib\site-packages (from transformers) (24.2)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\lenovo\anaconda3\lib\site-packages (from transformers) (0.21.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\lenovo\anaconda3\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\lenovo\anaconda3\lib\site-packages (from transformers) (2022.7.9)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.59 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain-huggingface) (0.3.60)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: langchain<1.0.0,>=0.3.25 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain-community) (0.3.25)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain-community) (3.11.18)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain-community) (1.4.39)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain-community) (9.1.2)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain-community) (0.3.42)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain-community) (2.9.1)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (4.23.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (5.1.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (32.0.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (1.33.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (1.33.1)
# Requirement already satisfied: typer>=0.9.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (0.15.4)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (1.33.1)
# Requirement already satisfied: importlib-resources in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (3.10.18)
# Requirement already satisfied: pydantic>=1.9 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (2.11.2)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (0.54b1)
# Requirement already satisfied: build>=1.0.3 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (1.2.2.post1)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (1.71.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (1.22.0)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (0.34.2)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: rich>=10.11.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (14.0.0)
# Requirement already satisfied: fastapi==0.115.9 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (0.115.9)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\lenovo\anaconda3\lib\site-packages (from chromadb) (4.0.1)
# Requirement already satisfied: starlette<0.46.0,>=0.40.0 in c:\users\lenovo\anaconda3\lib\site-packages (from fastapi==0.115.9->chromadb) (0.45.3)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.4.4)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Requirement already satisfied: pyproject_hooks in c:\users\lenovo\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (2.0.1)
# Requirement already satisfied: colorama in c:\users\lenovo\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\lenovo\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\lenovo\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: certifi in c:\users\lenovo\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (2023.5.7)
# Requirement already satisfied: httpcore==1.* in c:\users\lenovo\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.7)
# Requirement already satisfied: idna in c:\users\lenovo\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (3.4)
# Requirement already satisfied: anyio in c:\users\lenovo\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (4.9.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\lenovo\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\lenovo\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.2)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\lenovo\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\lenovo\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.4.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\lenovo\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.25.0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.38.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\lenovo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.58.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\lenovo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: six>=1.9.0 in c:\users\lenovo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\lenovo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: durationpy>=0.7 in c:\users\lenovo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: requests-oauthlib in c:\users\lenovo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\lenovo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.26.14)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain<1.0.0,>=0.3.25->langchain-community) (0.3.8)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\lenovo\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (1.33)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\lenovo\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: flatbuffers in c:\users\lenovo\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Requirement already satisfied: sympy in c:\users\lenovo\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.3)
# Requirement already satisfied: coloredlogs in c:\users\lenovo\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: protobuf in c:\users\lenovo\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.4)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.6.1)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.18)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.33.1 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.33.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.69.2)
# Requirement already satisfied: opentelemetry-proto==1.33.1 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.33.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.54b1 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.54b1)
# Requirement already satisfied: opentelemetry-util-http==0.54b1 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.54b1)
# Requirement already satisfied: opentelemetry-instrumentation==0.54b1 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.54b1)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.54b1 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.54b1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-instrumentation==0.54b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.14.1)
# Requirement already satisfied: asgiref~=3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from opentelemetry-instrumentation-asgi==0.54b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\lenovo\anaconda3\lib\site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\lenovo\anaconda3\lib\site-packages (from posthog>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: pydantic-core==2.33.1 in c:\users\lenovo\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (0.4.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.1.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\lenovo\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\lenovo\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (2.0.1)
# Requirement already satisfied: networkx in c:\users\lenovo\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (2.8.4)
# Requirement already satisfied: jinja2 in c:\users\lenovo\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: click<8.2,>=8.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (8.0.4)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\lenovo\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\lenovo\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.5)
# Requirement already satisfied: websockets>=10.4 in c:\users\lenovo\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (2.2.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\lenovo\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (1.1.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\lenovo\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\lenovo\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: zipp>=3.20 in c:\users\lenovo\anaconda3\lib\site-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.21.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\lenovo\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (2.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: sniffio>=1.1 in c:\users\lenovo\anaconda3\lib\site-packages (from anyio->httpx>=0.27.0->chromadb) (1.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\lenovo\anaconda3\lib\site-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.2.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (0.4.3)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\lenovo\anaconda3\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.1)
# Requirement already satisfied: pyreadline3 in c:\users\lenovo\anaconda3\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\lenovo\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.8)
# Installing collected packages: transformers, sentence-transformers
# Successfully installed sentence-transformers-4.1.0 transformers-4.52.1

# %%
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import Chroma
from langchain.docstore.document import Document

#  Use offline model
embedding = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")

# Convert chunks to documents
documents = [
    Document(page_content=chunk, metadata={"source": f"Resume_Chunk_{i+1}"})
    for i, chunk in enumerate(resume_chunks)
]

#  Store vectors in ChromaDB
vector_db = Chroma.from_documents(
    documents,
    embedding=embedding,
    persist_directory="resume_chroma_local"
)
vector_db.persist()

print(" Successfully stored using local embeddings.")

# %%
from langchain_community.vectorstores import Chroma
from langchain_community.embeddings import HuggingFaceEmbeddings

# Reconnect to saved vector DB
embedding = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
vector_db = Chroma(
    persist_directory="resume_chroma_local",
    embedding_function=embedding
)
retriever = vector_db.as_retriever(search_kwargs={"k": 3})

# %%
from transformers import pipeline

# Load a local Q&A model (no API needed)
qa_pipeline = pipeline("question-answering", model="deepset/roberta-base-squad2")

# %%
def ask_resume_question(query: str):
    # Step 1: Get top matching documents
    docs = retriever.get_relevant_documents(query)
    
    # Step 2: Merge content into context
    context = "\n\n".join(doc.page_content for doc in docs)

    # Step 3: Run QA pipeline
    answer = qa_pipeline({
        'context': context,
        'question': query
    })

    # Step 4: Return result with citations
    cited_sources = [doc.metadata['source'] for doc in docs]
    return {
        "question": query,
        "answer": answer['answer'],
        "confidence": answer['score'],
        "citations": cited_sources
    }

# %% [markdown]
# # Submitted by Kaameshwar Rai
